# %%
import pandas as pd
import  numpy as np

# %%
df = pd.read_csv('cleaned_smartphone.csv')

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    index brand_names                      model  price  rating  \
# 0      2     oneplus              OnePlus 11 5G  54999    89.0
# 1      3     oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4     samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5    motorola       Motorola Moto G62 5G  14999    81.0
# 4      6      realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df.columns
# Out:
# Index(['index', 'brand_names', 'model', 'price', 'rating', 'sim', 'processor',
#        'ram', 'RAM', 'ROM', 'Processor_speed', 'Processor_name',
#        'Processor_Company', 'Number_of_Cores', 'Processor_Speed(Num)',
#        'battery', 'Fast_Charging_in_(Watts)', 'Fast_Charging_There?',
#        'Battery_Capacity', 'display', 'Screen_Size(inches)', 'Resolution',
#        'Screen_Rate', 'Punch_Hole/Drop_Notch', 'camera', 'Type of rear cams',
#        'Rear Cam (primary_lens)', 'Type of Front cams',
#        'Front Cam(primary_lens)', 'Memory_Card_Supported_Or_Not', 'Capacity',
#        'SIM_Type', 'OS_Type', 'OS_Version', 'Contains_5G', 'Has_NFC',
#        'Has_IR_Blaster'],
#       dtype='object')

# %%
# 0 , 2 , 1 , 3 , 4 ,  5 , 31 , 34 , 35 , 36 , 6  , 11 , 12,13,14 ,  10 , 8 , 9 , 18 , 17 , 16 , 20 , 21 , 22 , 23 , 25 , 26
# 27 , 28 , 29 , 30 , 32 , 33

# %%
len(df.columns)
# Out:
# 37

# %%
temp_df = df.iloc[:,[0,2,1,3,4,5,31,34,35,36,6,11,12,13,14,10,8,9,18,17,16,20,21,22,23,25,26,27,28,29,30,32,33]]

# %%
temp_df.shape
# Out:
# (985, 33)

# %%
temp_df.columns
# Out:
# Index(['index', 'model', 'brand_names', 'price', 'rating', 'sim', 'SIM_Type',
#        'Contains_5G', 'Has_NFC', 'Has_IR_Blaster', 'processor',
#        'Processor_name', 'Processor_Company', 'Number_of_Cores',
#        'Processor_Speed(Num)', 'Processor_speed', 'RAM', 'ROM',
#        'Battery_Capacity', 'Fast_Charging_There?', 'Fast_Charging_in_(Watts)',
#        'Screen_Size(inches)', 'Resolution', 'Screen_Rate',
#        'Punch_Hole/Drop_Notch', 'Type of rear cams', 'Rear Cam (primary_lens)',
#        'Type of Front cams', 'Front Cam(primary_lens)',
#        'Memory_Card_Supported_Or_Not', 'Capacity', 'OS_Type', 'OS_Version'],
#       dtype='object')

# %%
temp_df.isnull().sum()
# Out:
# index                             0
# model                             0
# brand_names                       0
# price                             0
# rating                          106
# sim                               0
# SIM_Type                          0
# Contains_5G                       0
# Has_NFC                           0
# Has_IR_Blaster                    0
# processor                         2
# Processor_name                   22
# Processor_Company                22
# Number_of_Cores                   9
# Processor_Speed(Num)             45
# Processor_speed                  56
# RAM                               3
# ROM                               0
# Battery_Capacity                  0
# Fast_Charging_There?            137
# Fast_Charging_in_(Watts)        205
# Screen_Size(inches)               0
# Resolution                        0
# Screen_Rate                       0
# Punch_Hole/Drop_Notch           412
# Type of rear cams                 0
# ...

# %%
temp_df.head()
# Out:
#    index                      model brand_names  price  rating  \
# 0      2              OnePlus 11 5G     oneplus  54999    89.0
# 1      3  OnePlus Nord CE 2 Lite 5G     oneplus  19989    81.0
# 2      4      Samsung Galaxy A14 5G     samsung  16499    75.0
# 3      5       Motorola Moto G62 5G    motorola  14999    81.0
# 4      6         Realme 10 Pro Plus      realme  24999    82.0
#
#                                        sim  SIM_Type  Contains_5G  Has_NFC  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  Dual Sim            1        1
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi  Dual Sim            1        0
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi  Dual Sim            1        0
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi  Dual Sim            1        0
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi  Dual Sim            1        0
#
#    Has_IR_Blaster                                        processor  \
# ...

# %%
temp_df.drop(columns = ['sim','processor'],inplace =  True)
# Out:
# C:\Users\91700\AppData\Local\Temp\ipykernel_5320\4115299980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df.drop(columns = ['sim','processor'],inplace =  True)

# %%
temp_df = temp_df

# %%
temp_df['Number_of_Cores'].value_counts()
# Out:
# Octa Core    899
# Hexa Core     39
# Quad Core     37
# Dual Core      1
# Name: Number_of_Cores, dtype: int64

# %%
temp_df['Has_IR_Blaster'].replace({
    1:True,0:False
},inplace = True)
# Out:
# C:\Users\91700\AppData\Local\Temp\ipykernel_5320\1744488926.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['Has_IR_Blaster'].replace({

# %%
temp_df['Contains_5G'].sample(10)
# Out:
# 409    1
# 619    0
# 845    0
# 182    1
# 559    1
# 191    1
# 211    1
# 974    1
# 774    1
# 89     1
# Name: Contains_5G, dtype: int64

# %%
temp_df['Contains_5G'].dtype
# Out:
# dtype('int64')

# %%
temp_df['RAM'].value_counts()
# Out:
# 8 GB      339
# 6 GB      234
# 4 GB      215
# 12 GB      85
# 3 GB       54
# 2 GB       32
# 16 GB       9
# 1 GB        8
# 512 MB      2
# 18 GB       2
# 64 MB       1
# 256 MB      1
# Name: RAM, dtype: int64

# %%
print(temp_df['Battery_Capacity'].shape)
# Out:
# (985,)

# %%
pd.set_option('display.max_columns',None)

# %%
temp_df['Battery_Capacity'].head(1).values[0]
# Out:
# '5000 mAh'

# %%
temp_df['Battery_Capacity'] = temp_df['Battery_Capacity'].str.split(' ').str.get(0).astype(float)
# Out:
# C:\Users\91700\AppData\Local\Temp\ipykernel_5320\54728479.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['Battery_Capacity'] = temp_df['Battery_Capacity'].str.split(' ').str.get(0).astype(float)

# %%
temp_df['Battery_Capacity']
# Out:
# 0      5000.0
# 1      5000.0
# 2      5000.0
# 3      5000.0
# 4      5000.0
#         ...
# 980    5000.0
# 981    5000.0
# 982    5080.0
# 983    5000.0
# 984    5000.0
# Name: Battery_Capacity, Length: 985, dtype: float64

# %%
temp_df.rename(columns={
    'Type of rear cams' : 'Num_of_rear_cam',
    'Type of Front cams' : 'Num_of_front_cam'
},inplace = True)
# Out:
# C:\Users\91700\AppData\Local\Temp\ipykernel_5320\2071566042.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df.rename(columns={

# %%
pd.set_option('display.max_rows',None)

# %%
temp_df[temp_df['Num_of_rear_cam'] == 'Single']
# Out:
# Empty DataFrame
# Columns: [index, model, brand_names, price, rating, SIM_Type, Contains_5G, Has_NFC, Has_IR_Blaster, Processor_name, Processor_Company, Number_of_Cores, Processor_Speed(Num), Processor_speed, RAM, ROM, Battery_Capacity, Fast_Charging_There?, Fast_Charging_in_(Watts), Screen_Size(inches), Resolution, Screen_Rate, Punch_Hole/Drop_Notch, Num_of_rear_cam, Rear Cam (primary_lens), Num_of_front_cam, Front Cam(primary_lens), Memory_Card_Supported_Or_Not, Capacity, OS_Type, OS_Version]
# Index: []

# %%
ind = temp_df[temp_df['Num_of_rear_cam'].str.contains('MP')]['Num_of_rear_cam'].index

# %%
temp_df['Num_of_rear_cam'].unique()
# Out:
# array(['Triple', 'Dual', 'Quad', '13\u2009MP', '8\u2009MP', '5\u2009MP',
#        '12\u2009MP', 'Penta', '2\u2009MP', '12.2\u2009MP', '0.3\u2009MP',
#        '16\u2009MP', '20\u2009MP'], dtype=object)

# %%
temp_df.loc[ind, 'Num_of_rear_cam'] = 'Single'

# %%
temp_df['Num_of_rear_cam'].replace(
{
    'Triple':3,
    'Dual':2,
    'Quad':4,
    'Single':1,
    'Penta':5
},inplace = True)
# Out:
# C:\Users\91700\AppData\Local\Temp\ipykernel_5320\671805965.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['Num_of_rear_cam'].replace(

# %%
temp_df.head()
# Out:
#    index                      model brand_names  price  rating  SIM_Type  \
# 0      2              OnePlus 11 5G     oneplus  54999    89.0  Dual Sim
# 1      3  OnePlus Nord CE 2 Lite 5G     oneplus  19989    81.0  Dual Sim
# 2      4      Samsung Galaxy A14 5G     samsung  16499    75.0  Dual Sim
# 3      5       Motorola Moto G62 5G    motorola  14999    81.0  Dual Sim
# 4      6         Realme 10 Pro Plus      realme  24999    82.0  Dual Sim
#
#    Contains_5G  Has_NFC  Has_IR_Blaster     Processor_name Processor_Company  \
# 0            1        1           False  Snapdragon 8 Gen2        Snapdragon
# 1            1        0           False     Snapdragon 695        Snapdragon
# 2            1        0           False        Exynos 1330            Exynos
# 3            1        0           False    Snapdragon  695        Snapdragon
# 4            1        0           False     Dimensity 1080         Dimensity
#
# ...

# %%
temp_df['OS_Type'].unique()
# Out:
# array(['Android', 'iOS', nan, 'HarmonyOS', 'Hongmeng', 'Pragati', 'RTOS',
#        'Harmony', 'EMUI'], dtype=object)

# %%
temp_df['OS_Type'].value_counts()
# Out:
# Android      897
# iOS           46
# HarmonyOS      4
# Hongmeng       2
# Harmony        2
# EMUI           2
# Pragati        1
# RTOS           1
# Name: OS_Type, dtype: int64

# %%
ind = temp_df[temp_df['OS_Type'].isin(['HarmonyOS','Hongmeng','Harmony','EMUI','Pragati','RTOS'])].index

# %%
temp_df.loc[ind,'OS_Type'] = 'Others'

# %%
temp_df['OS_Type'].value_counts()
# Out:
# Android    897
# iOS         46
# Others      12
# Name: OS_Type, dtype: int64

# %%
temp_df.head()
# Out:
#    index                      model brand_names  price  rating  SIM_Type  \
# 0      2              OnePlus 11 5G     oneplus  54999    89.0  Dual Sim
# 1      3  OnePlus Nord CE 2 Lite 5G     oneplus  19989    81.0  Dual Sim
# 2      4      Samsung Galaxy A14 5G     samsung  16499    75.0  Dual Sim
# 3      5       Motorola Moto G62 5G    motorola  14999    81.0  Dual Sim
# 4      6         Realme 10 Pro Plus      realme  24999    82.0  Dual Sim
#
#    Contains_5G  Has_NFC  Has_IR_Blaster     Processor_name Processor_Company  \
# 0            1        1           False  Snapdragon 8 Gen2        Snapdragon
# 1            1        0           False     Snapdragon 695        Snapdragon
# 2            1        0           False        Exynos 1330            Exynos
# 3            1        0           False    Snapdragon  695        Snapdragon
# 4            1        0           False     Dimensity 1080         Dimensity
#
# ...

# %%
temp_df.dtypes
# Out:
# index                             int64
# model                            object
# brand_names                      object
# price                             int64
# rating                          float64
# SIM_Type                         object
# Contains_5G                       int64
# Has_NFC                           int64
# Has_IR_Blaster                     bool
# Processor_name                   object
# Processor_Company                object
# Number_of_Cores                  object
# Processor_Speed(Num)            float64
# Processor_speed                  object
# RAM                              object
# ROM                              object
# Battery_Capacity                float64
# Fast_Charging_There?             object
# Fast_Charging_in_(Watts)        float64
# Screen_Size(inches)             float64
# Resolution                       object
# Screen_Rate                       int64
# Punch_Hole/Drop_Notch            object
# ...

# %%
temp_df.to_csv('Cleaned_Version_2.csv')

# %%
temp_df.head()
# Out:
#    index                      model brand_names  price  rating  SIM_Type  \
# 0      2              OnePlus 11 5G     oneplus  54999    89.0  Dual Sim
# 1      3  OnePlus Nord CE 2 Lite 5G     oneplus  19989    81.0  Dual Sim
# 2      4      Samsung Galaxy A14 5G     samsung  16499    75.0  Dual Sim
# 3      5       Motorola Moto G62 5G    motorola  14999    81.0  Dual Sim
# 4      6         Realme 10 Pro Plus      realme  24999    82.0  Dual Sim
#
#    Contains_5G  Has_NFC  Has_IR_Blaster     Processor_name Processor_Company  \
# 0            1        1           False  Snapdragon 8 Gen2        Snapdragon
# 1            1        0           False     Snapdragon 695        Snapdragon
# 2            1        0           False        Exynos 1330            Exynos
# 3            1        0           False    Snapdragon  695        Snapdragon
# 4            1        0           False     Dimensity 1080         Dimensity
#
# ...

# %%
temp_df['Num_of_front_cam'].replace(
{
    'Triple':3,
    'Dual':2,
    'Quad':4,
    'Single':1,
    'Penta':5
},inplace = True)
# Out:
# C:\Users\91700\AppData\Local\Temp\ipykernel_5320\4097373176.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['Num_of_front_cam'].replace(

# %%
temp_df['Has_NFC'].replace({
    1:True,0:False
},inplace = True)
# Out:
# C:\Users\91700\AppData\Local\Temp\ipykernel_5320\3538645703.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['Has_NFC'].replace({

# %%
temp_df.head()
# Out:
#    index                      model brand_names  price  rating  SIM_Type  \
# 0      2              OnePlus 11 5G     oneplus  54999    89.0  Dual Sim
# 1      3  OnePlus Nord CE 2 Lite 5G     oneplus  19989    81.0  Dual Sim
# 2      4      Samsung Galaxy A14 5G     samsung  16499    75.0  Dual Sim
# 3      5       Motorola Moto G62 5G    motorola  14999    81.0  Dual Sim
# 4      6         Realme 10 Pro Plus      realme  24999    82.0  Dual Sim
#
#    Contains_5G  Has_NFC  Has_IR_Blaster     Processor_name Processor_Company  \
# 0         True     True           False  Snapdragon 8 Gen2        Snapdragon
# 1         True    False           False     Snapdragon 695        Snapdragon
# 2         True    False           False        Exynos 1330            Exynos
# 3         True    False           False    Snapdragon  695        Snapdragon
# 4         True    False           False     Dimensity 1080         Dimensity
#
# ...
