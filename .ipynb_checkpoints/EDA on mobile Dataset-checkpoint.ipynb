# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
# Requirement already satisfied: pillow in c:\users\91700\anaconda3\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: matplotlib in c:\users\91700\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\91700\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\91700\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\91700\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\91700\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\91700\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91700\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\91700\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\91700\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
from wordcloud import STOPWORDS

# %%
df = pd.read_csv('Cleaned_Version_2.csv')

# %%
df = df.iloc[:,1:]

# %%
pd.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#    index                      model brand_names  price  rating  SIM_Type  \
# 0      2              OnePlus 11 5G     oneplus  54999    89.0  Dual Sim
# 1      3  OnePlus Nord CE 2 Lite 5G     oneplus  19989    81.0  Dual Sim
# 2      4      Samsung Galaxy A14 5G     samsung  16499    75.0  Dual Sim
# 3      5       Motorola Moto G62 5G    motorola  14999    81.0  Dual Sim
# 4      6         Realme 10 Pro Plus      realme  24999    82.0  Dual Sim
#
#    Contains_5G  Has_NFC  Has_IR_Blaster     Processor_name Processor_Company  \
# 0         True     True           False  Snapdragon 8 Gen2        Snapdragon
# 1         True    False           False     Snapdragon 695        Snapdragon
# 2         True    False           False        Exynos 1330            Exynos
# 3         True    False           False    Snapdragon  695        Snapdragon
# 4         True    False           False     Dimensity 1080         Dimensity
#
#   Number_of_Cores  Processor_Speed(Num)     Processor_speed    RAM     ROM  \
# 0       Octa Core                   3.2   3.2 GHz Processor  12 GB  256 GB
# 1       Octa Core                   2.2   2.2 GHz Processor   6 GB  128 GB
# 2       Octa Core                   2.4   2.4 GHz Processor   4 GB   64 GB
# 3       Octa Core                   2.2   2.2 GHz Processor   6 GB  128 GB
# 4       Octa Core                   2.6   2.6 GHz Processor   6 GB  128 GB
#
#    Battery_Capacity    Fast_Charging_There?  Fast_Charging_in_(Watts)  \
# 0            5000.0  Contains Fast Charging                     100.0
# 1            5000.0  Contains Fast Charging                      33.0
# 2            5000.0  Contains Fast Charging                      15.0
# 3            5000.0  Contains Fast Charging                       NaN
# 4            5000.0  Contains Fast Charging                      67.0
#
#    Screen_Size(inches)      Resolution  Screen_Rate Punch_Hole/Drop_Notch  \
# 0                 6.70  1440 x 3216 px          120            Punch Hole
# 1                 6.59  1080 x 2412 px          120            Punch Hole
# 2                 6.60  1080 x 2408 px           90      Water Drop Notch
# 3                 6.55  1080 x 2400 px          120            Punch Hole
# 4                 6.70  1080 x 2412 px          120            Punch Hole
#
#    Num_of_rear_cam Rear Cam (primary_lens)  Num_of_front_cam  \
# 0                3                     50                  1
# 1                3                     64                  1
# 2                3                     50                  1
# 3                3                     50                  1
# 4                3                    108                  1
#
#   Front Cam(primary_lens) Memory_Card_Supported_Or_Not Capacity  OS_Type  \
# 0                     16     Memory Card Not Supported      NaN  Android
# 1                     16          Memory Card (Hybrid)      1TB  Android
# 2                     13         Memory Card Supported      1TB  Android
# 3                     16          Memory Card (Hybrid)      1TB  Android
# 4                     16     Memory Card Not Supported      NaN  Android
#
#   OS_Version
# 0        v13
# 1        v12
# 2        v13
# 3        v12
# 4        v13

# %% [markdown]
# ## Univariate Analysis.

# %% [markdown]
# ##### Brand Names

# %% [markdown]
# Insights : 1. The major Companies (with most products) Listed on the SmartPrix website are namely xiaomi , samsung , vivo , realme , oppo .

# %%
fields  = ['brand_names']

# %%
text2 = pd.read_csv('Cleaned_Version_2.csv', usecols=fields)

# %%
text3 = ' '.join(text2['brand_names'])
wordcloud2 = WordCloud().generate(text3)
# Generate plot
plt.figure(figsize = (20,7))
plt.imshow(wordcloud2)
plt.axis("off")
plt.show()

# %%
df['brand_names'].value_counts().nlargest(5)
# Out:
# xiaomi     134
# samsung    132
# vivo       111
# realme      97
# oppo        88
# Name: brand_names, dtype: int64

# %%
temp = df['brand_names'].value_counts().nlargest(5)
temp = temp.reset_index()

# %%
temp
# Out:
#      index  brand_names
# 0   xiaomi          134
# 1  samsung          132
# 2     vivo          111
# 3   realme           97
# 4     oppo           88

# %%
sns.barplot(data = temp ,x = 'index' ,y  = 'brand_names')
plt.xticks(rotation = 45)
plt.show()

# %%
# Lets Calculate the Percentage. 
plt.figure(figsize = (7,7))
df['brand_names'].value_counts().nlargest(5).plot(kind = 'pie',autopct = '%.2f%%')
# Out:
# <AxesSubplot:ylabel='brand_names'>

# %%
df['brand_names'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ##### Price

# %% [markdown]
# 1. The Data is highly skewed.
# 2. The Data Skewness was due to Some signature phones which were removed high end phones with brand mes(Apple,Samsung) were kept in the data.
# 3. The Data is not normally distributed.
# 4. Data contains a lot of outliers.
# 5. Most High end Phones belong to the apple and Samsung Companies.

# %%
df['price'].describe()
# Out:
# count       985.000000
# mean      32388.608122
# std       39475.086721
# min        3499.000000
# 25%       12999.000000
# 50%       19990.000000
# 75%       35389.000000
# max      650000.000000
# Name: price, dtype: float64

# %%
df['price'].skew()
# Out:
# 6.59507711973288

# %%
plt.figure(figsize = (10,8))
sns.histplot(data = df , x = 'price',kde = True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
df[df['price'] > 200000].index
# Out:
# Int64Index([428, 479, 891, 956], dtype='int64')

# %%
df.drop(index =df[df['price'] > 200000].index ,inplace = True )

# %%
plt.figure(figsize = (10,8))
sns.histplot(data = df , x = 'price',kde = True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
sns.boxplot(data = df , y = 'price')
# Out:
# <AxesSubplot:ylabel='price'>

# %%
df[df['price'] > 75000]['brand_names'].value_counts().nlargest(5)
# Out:
# apple      26
# samsung    20
# oppo        7
# vivo        7
# xiaomi      4
# Name: brand_names, dtype: int64

# %% [markdown]
# ##### Rating

# %% [markdown]
# 1. Data is nearly normal.
# 2. There are no outliers and the data is well balanced

# %%
df['rating'].describe()
# Out:
# count    876.000000
# mean      78.262557
# std        7.387218
# min       60.000000
# 25%       74.000000
# 50%       80.000000
# 75%       84.000000
# max       89.000000
# Name: rating, dtype: float64

# %%
df['rating'].skew()
# Out:
# -0.6980929290123329

# %%
df['rating'].isnull().sum()
# Out:
# 105

# %%
sns.boxplot(data = df , y = 'rating')
# Out:
# <AxesSubplot:ylabel='rating'>

# %%
sns.displot(data =df , x  = 'rating' , kde = 'True')

# %%
df.head()
# Out:
#    index                      model brand_names  price  rating  SIM_Type  \
# 0      2              OnePlus 11 5G     oneplus  54999    89.0  Dual Sim
# 1      3  OnePlus Nord CE 2 Lite 5G     oneplus  19989    81.0  Dual Sim
# 2      4      Samsung Galaxy A14 5G     samsung  16499    75.0  Dual Sim
# 3      5       Motorola Moto G62 5G    motorola  14999    81.0  Dual Sim
# 4      6         Realme 10 Pro Plus      realme  24999    82.0  Dual Sim
#
#    Contains_5G  Has_NFC  Has_IR_Blaster     Processor_name Processor_Company  \
# 0         True     True           False  Snapdragon 8 Gen2        Snapdragon
# 1         True    False           False     Snapdragon 695        Snapdragon
# 2         True    False           False        Exynos 1330            Exynos
# 3         True    False           False    Snapdragon  695        Snapdragon
# 4         True    False           False     Dimensity 1080         Dimensity
#
#   Number_of_Cores  Processor_Speed(Num)     Processor_speed    RAM     ROM  \
# 0       Octa Core                   3.2   3.2 GHz Processor  12 GB  256 GB
# 1       Octa Core                   2.2   2.2 GHz Processor   6 GB  128 GB
# 2       Octa Core                   2.4   2.4 GHz Processor   4 GB   64 GB
# 3       Octa Core                   2.2   2.2 GHz Processor   6 GB  128 GB
# 4       Octa Core                   2.6   2.6 GHz Processor   6 GB  128 GB
#
#    Battery_Capacity    Fast_Charging_There?  Fast_Charging_in_(Watts)  \
# 0            5000.0  Contains Fast Charging                     100.0
# 1            5000.0  Contains Fast Charging                      33.0
# 2            5000.0  Contains Fast Charging                      15.0
# 3            5000.0  Contains Fast Charging                       NaN
# 4            5000.0  Contains Fast Charging                      67.0
#
#    Screen_Size(inches)      Resolution  Screen_Rate Punch_Hole/Drop_Notch  \
# 0                 6.70  1440 x 3216 px          120            Punch Hole
# 1                 6.59  1080 x 2412 px          120            Punch Hole
# 2                 6.60  1080 x 2408 px           90      Water Drop Notch
# 3                 6.55  1080 x 2400 px          120            Punch Hole
# 4                 6.70  1080 x 2412 px          120            Punch Hole
#
#    Num_of_rear_cam Rear Cam (primary_lens)  Num_of_front_cam  \
# 0                3                     50                  1
# 1                3                     64                  1
# 2                3                     50                  1
# 3                3                     50                  1
# 4                3                    108                  1
#
#   Front Cam(primary_lens) Memory_Card_Supported_Or_Not Capacity  OS_Type  \
# 0                     16     Memory Card Not Supported      NaN  Android
# 1                     16          Memory Card (Hybrid)      1TB  Android
# 2                     13         Memory Card Supported      1TB  Android
# 3                     16          Memory Card (Hybrid)      1TB  Android
# 4                     16     Memory Card Not Supported      NaN  Android
#
#   OS_Version
# 0        v13
# 1        v12
# 2        v13
# 3        v12
# 4        v13

# %% [markdown]
# ##### Sim Type

# %% [markdown]
# 1. Most of the Phones today come with dual sim feature.
# 2. Not a good feature to train out ML model.

# %%
df['SIM_Type'].value_counts()
# Out:
# Dual Sim      965
# Single Sim     16
# Name: SIM_Type, dtype: int64

# %%
df['SIM_Type'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (7,7))
df['SIM_Type'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='SIM_Type'>

# %% [markdown]
# #### 5G

# %% [markdown]
# 1. This is a good feauture for training ML model.

# %%
df['Contains_5G'].value_counts()
# Out:
# True     548
# False    433
# Name: Contains_5G, dtype: int64

# %%
plt.figure(figsize = (7,7))
df['Contains_5G'].value_counts().plot(kind = 'pie',autopct = '%.2f%%')
# Out:
# <AxesSubplot:ylabel='Contains_5G'>

# %%
sns.countplot(data = df , x = 'Contains_5G')
# Out:
# <AxesSubplot:xlabel='Contains_5G', ylabel='count'>

# %% [markdown]
# ##### NFC Availability

# %% [markdown]
# 1. As NFC facility is only found in branded phones this can be a good feature for ML model.

# %%
df['Has_NFC'].value_counts()
# Out:
# False    592
# True     389
# Name: Has_NFC, dtype: int64

# %%
df['Has_NFC'].isnull().sum()
# Out:
# 0

# %%
df['Has_NFC'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Has_NFC'>

# %% [markdown]
# ##### Processor Company

# %%
df['Processor_Company'].value_counts().index
# Out:
# Index(['Snapdragon', 'Helio', 'Dimensity', 'Exynos', 'Bionic', 'Unisoc',
#        'Tiger', 'Google', 'Kirin', 'A13', 'Qualcomm', 'Spreadtrum', 'SC9863A',
#        'Mediatek', 'Apple', 'Fusion', 'Sanpdragon', 'Samsung'],
#       dtype='object')

# %%
df['Processor_Company'].replace(
{
    'Sanpdragon' : 'Snapdragon'
},inplace = True)

# %%
df['Processor_Company'].value_counts()
# Out:
# Snapdragon    407
# Helio         201
# Dimensity     177
# Exynos         49
# Bionic         39
# Unisoc         27
# Tiger          24
# Google          9
# Kirin           6
# A13             5
# Qualcomm        5
# Spreadtrum      4
# SC9863A         2
# Apple           1
# Fusion          1
# Mediatek        1
# Samsung         1
# Name: Processor_Company, dtype: int64

# %%
df[df['Processor_Company'] == 'Samsung'].index
# Out:
# Int64Index([843], dtype='int64')

# %%
df.loc[df[df['Processor_Company'] == 'Samsung'].index,'Processor_Company'] = 'Exynos'

# %%
df.loc[df[df['Processor_Company'] == 'Apple'].index,'Processor_Company'] = 'A13'

# %%
df['Processor_Company'].value_counts().nlargest(5)
# Out:
# Snapdragon    407
# Helio         201
# Dimensity     177
# Exynos         50
# Bionic         39
# Name: Processor_Company, dtype: int64

# %%
df['Processor_Company'].value_counts().nlargest(5).plot(kind = 'bar')
plt.show()

# %% [markdown]
# ##### Processor Speed

# %% [markdown]
# 1. Most of the Processors work at a freq of 2 - 2.50 GHz.

# %%
sns.histplot(data = df , x = 'Processor_Speed(Num)' , bins = [1,1.5,2,2.5,4])
# Out:
# <AxesSubplot:xlabel='Processor_Speed(Num)', ylabel='Count'>

# %%
df['Processor_Speed(Num)'].value_counts()
# Out:
# 2.00    145
# 2.20    135
# 2.40    128
# 3.20     93
# 2.30     86
# 3.00     53
# 2.84     36
# 2.05     28
# 2.50     23
# 1.80     23
# 1.60     20
# 2.85     19
# 3.22     18
# 3.10     15
# 2.60     13
# 2.90     13
# 1.82     10
# 1.30     10
# 2.73      9
# 2.80      8
# 3.05      8
# 2.36      8
# 2.70      5
# 1.40      5
# 2.65      5
# 2.96      3
# 1.50      3
# 1.10      2
# 3.13      2
# 2.86      2
# 2.35      1
# 2.37      1
# 1.99      1
# 1.95      1
# 2.10      1
# 1.20      1
# Name: Processor_Speed(Num), dtype: int64

# %% [markdown]
# ##### Number of Cores.

# %%
df['Number_of_Cores'].value_counts()
# Out:
# Octa Core    895
# Hexa Core     39
# Quad Core     37
# Dual Core      1
# Name: Number_of_Cores, dtype: int64

# %%
plt.figure(figsize = (8,8))
df['Number_of_Cores'].value_counts().plot(kind = 'pie',autopct=  '%.2f%%')
# Out:
# <AxesSubplot:ylabel='Number_of_Cores'>

# %% [markdown]
# ##### RAM

# %% [markdown]
# 1. Most of the Phones now comes with a 8 GB Ram
# 2. Has 3 Null values.

# %%
df['RAM'].value_counts()
# Out:
# 8 GB      338
# 6 GB      234
# 4 GB      215
# 12 GB      84
# 3 GB       54
# 2 GB       31
# 16 GB       9
# 1 GB        8
# 512 MB      2
# 18 GB       2
# 64 MB       1
# 256 MB      1
# Name: RAM, dtype: int64

# %%
t  = df.groupby('RAM').size().reset_index()

# %%
t.columns = ['RAM','COUNT']

# %%
t
# Out:
#        RAM  COUNT
# 0     1 GB      8
# 1    12 GB     84
# 2    16 GB      9
# 3    18 GB      2
# 4     2 GB     31
# 5   256 MB      1
# 6     3 GB     54
# 7     4 GB    215
# 8   512 MB      2
# 9     6 GB    234
# 10   64 MB      1
# 11    8 GB    338

# %%
t[t['COUNT'] > 50]['RAM'].values
# Out:
# array(['12 GB', '3 GB', '4 GB', '6 GB', '8 GB'], dtype=object)

# %%
plt.figure(figsize = (8,8))
df[df['RAM'].isin(t[t['COUNT'] > 50]['RAM'].values)]['RAM'].value_counts().plot(kind = 'pie',autopct = '%.2f%%')
# Out:
# <AxesSubplot:ylabel='RAM'>

# %%
t  = df[df['RAM'].isin(t[t['COUNT'] > 50]['RAM'].values)]['RAM'].value_counts()

# %%
t = t.reset_index()
t
# Out:
#    index  RAM
# 0   8 GB  338
# 1   6 GB  234
# 2   4 GB  215
# 3  12 GB   84
# 4   3 GB   54

# %%
sns.barplot(data = t ,x = 'index',y='RAM')
# Out:
# <AxesSubplot:xlabel='index', ylabel='RAM'>

# %%
df['RAM'].isnull().sum()
# Out:
# 2

# %%
df[df['RAM'].isnull()]
# Out:
#      index                   model brand_names  price  rating  SIM_Type  \
# 436    441  Apple iPhone SE 3 2022       apple  43900     NaN  Dual Sim
# 740    764       Apple iPhone SE 4       apple  49990    60.0  Dual Sim
#
#      Contains_5G  Has_NFC  Has_IR_Blaster Processor_name Processor_Company  \
# 436         True     True           False    Bionic  A15            Bionic
# 740         True     True           False    Bionic  A15            Bionic
#
#     Number_of_Cores  Processor_Speed(Num)      Processor_speed  RAM    ROM  \
# 436       Hexa Core                  3.22   3.22 GHz Processor  NaN  64 GB
# 740       Hexa Core                  3.22   3.22 GHz Processor  NaN  64 GB
#
#      Battery_Capacity    Fast_Charging_There?  Fast_Charging_in_(Watts)  \
# 436            2018.0  Contains Fast Charging                      20.0
# 740            1642.0  Contains Fast Charging                      20.0
#
#      Screen_Size(inches)     Resolution  Screen_Rate Punch_Hole/Drop_Notch  \
# 436                  4.7  750 x 1334 px           60                   NaN
# 740                  6.1  750 x 1580 px           60                   NaN
#
#      Num_of_rear_cam Rear Cam (primary_lens)  Num_of_front_cam  \
# 436                1                     12                  1
# 740                1                     12                  1
#
#     Front Cam(primary_lens) Memory_Card_Supported_Or_Not Capacity OS_Type  \
# 436                      7     Memory Card Not Supported      NaN     iOS
# 740                   10.8     Memory Card Not Supported      NaN     iOS
#
#     OS_Version
# 436        v15
# 740        v16

# %% [markdown]
# ##### ROM

# %%
df['ROM'].value_counts().nlargest(5)
# Out:
# 128 GB    523
# 64 GB     192
# 256 GB    156
# 32 GB      67
# 512 GB     20
# Name: ROM, dtype: int64

# %%
plt.figure(figsize = (8,8))
df['ROM'].value_counts().nlargest(5).plot(kind = 'pie',autopct = '%.2f%%')
# Out:
# <AxesSubplot:ylabel='ROM'>

# %%
df['ROM'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ##### Battery

# %% [markdown]
# 1. Has a lot of outliers.
# 2. Apple provides very low battery capacity as compared to other devices.
# 3. According to the data mostly the list of Phones that are offering a lower battery life as compared to other phones includes Phones which are mostly above the  median price range.

# %%
df['Battery_Capacity'].describe()
# Out:
# count      981.000000
# mean      4780.153925
# std       1056.242577
# min       1150.000000
# 25%       4500.000000
# 50%       5000.000000
# 75%       5000.000000
# max      22000.000000
# Name: Battery_Capacity, dtype: float64

# %%
df[df['Battery_Capacity'] == 22000.000000]
# Out:
#      index         model brand_names  price  rating  SIM_Type  Contains_5G  \
# 847    876  Doogee V Max      doogee  45999    88.0  Dual Sim         True
#
#      Has_NFC  Has_IR_Blaster  Processor_name Processor_Company  \
# 847    False           False  Dimensity 1080         Dimensity
#
#     Number_of_Cores  Processor_Speed(Num)     Processor_speed    RAM     ROM  \
# 847       Octa Core                   2.6   2.6 GHz Processor  12 GB  256 GB
#
#      Battery_Capacity    Fast_Charging_There?  Fast_Charging_in_(Watts)  \
# 847           22000.0  Contains Fast Charging                      33.0
#
#      Screen_Size(inches)      Resolution  Screen_Rate Punch_Hole/Drop_Notch  \
# 847                 6.58  1080 x 2408 px          120      Water Drop Notch
#
#      Num_of_rear_cam Rear Cam (primary_lens)  Num_of_front_cam  \
# 847                3                    108                  1
#
#     Front Cam(primary_lens) Memory_Card_Supported_Or_Not Capacity  OS_Type  \
# 847                     32          Memory Card (Hybrid)      2TB  Android
#
#     OS_Version
# 847        v12

# %%
sns.boxplot(data = df , x = 'Battery_Capacity')
# Out:
# <AxesSubplot:xlabel='Battery_Capacity'>

# %%
df['Battery_Capacity'].isnull().sum()
# Out:
# 0

# %%
ax = sns.rugplot(data = df , x  = 'Battery_Capacity')
ax.set_ylim([1,200])
plt.show()

# %%
t = df[df['Battery_Capacity']>10000]

# %%
df.drop(index = t.index,inplace = True)

# %%
sns.scatterplot(data = df , x = 'Battery_Capacity' , y = 'price')
# Out:
# <AxesSubplot:xlabel='Battery_Capacity', ylabel='price'>

# %%
# lets calculate the IQR for the Battery Capacity.
# IQR = Q3 - Q1
# outliers detection formula boundary values are :  Q1 - 1.5*(IQR) and Q3 + 1.5*(IQR)

# %%
low_lim = 4500 - ((5000 - 4500)*1.5)
Upper_lim = 5000 + ((5000 - 4500)*1.5)

# %%
low_lim,Upper_lim
# Out:
# (3750.0, 5750.0)

# %%
df[(df['Battery_Capacity'] > 5750.0) | (df['Battery_Capacity'] < 3750.0)]
# Out:
#      index                     model brand_names  price  rating  SIM_Type  \
# 6        8           Apple iPhone 14       apple  65999    81.0  Dual Sim
# 15      17           Apple iPhone 13       apple  62999    79.0  Dual Sim
# 33      35           Apple iPhone 11       apple  38999    73.0  Dual Sim
# 45      47     Samsung Galaxy M33 5G     samsung  17478    81.0  Dual Sim
# 75      77            Gionee G13 Pro      gionee   6190     NaN  Dual Sim
# ..     ...                       ...         ...    ...     ...       ...
# 961    997  Samsung Galaxy A7 (2018)     samsung  21490    70.0  Dual Sim
# 962    998                 Vivo Y55S        vivo  13490     NaN  Dual Sim
# 967   1004                Doogee S99      doogee  14999    84.0  Dual Sim
# 971   1008               Oukitel WP9     oukitel  25899    72.0  Dual Sim
# 977   1014                 itel A23s        itel   4787     NaN  Dual Sim
#
#      Contains_5G  Has_NFC  Has_IR_Blaster       Processor_name  \
# 6           True     True           False           Bionic A15
# 15          True     True           False           Bionic A15
# 33         False     True           False           A13 Bionic
# 45          True     True           False         Exynos  1280
# 75         False    False           False          Tiger  T310
# ..           ...      ...             ...                  ...
# 961        False    False           False          Exynos 7885
# 962        False    False           False       Snapdragon 425
# 967        False     True           False            Helio G96
# 971        False     True           False            Helio P60
# 977        False    False           False  Spreadtrum  SC9832E
#
#     Processor_Company Number_of_Cores  Processor_Speed(Num)  \
# 6              Bionic       Hexa Core                  3.22
# 15             Bionic       Hexa Core                  3.22
# 33                A13       Hexa Core                  2.65
# 45             Exynos       Octa Core                  2.40
# 75              Tiger       Quad Core                  2.00
# ..                ...             ...                   ...
# 961            Exynos       Octa Core                  2.20
# 962        Snapdragon       Quad Core                  1.20
# 967             Helio       Octa Core                  2.05
# 971             Helio       Octa Core                  2.00
# 977        Spreadtrum       Quad Core                  1.40
#
#          Processor_speed   RAM     ROM  Battery_Capacity  \
# 6     3.22 GHz Processor  6 GB  128 GB            3279.0
# 15    3.22 GHz Processor  4 GB  128 GB            3240.0
# 33    2.65 GHz Processor  4 GB   64 GB            3110.0
# 45     2.4 GHz Processor  6 GB  128 GB            6000.0
# 75       2 GHz Processor  4 GB   32 GB            3500.0
# ..                   ...   ...     ...               ...
# 961    2.2 GHz Processor  4 GB   64 GB            3300.0
# 962    1.2 GHz Processor  3 GB   16 GB            2730.0
# 967   2.05 GHz Processor  8 GB  128 GB            6000.0
# 971      2 GHz Processor  6 GB  128 GB            8000.0
# 977    1.4 GHz Processor  2 GB   32 GB            3020.0
#
#        Fast_Charging_There?  Fast_Charging_in_(Watts)  Screen_Size(inches)  \
# 6    Contains Fast Charging                       NaN                 6.10
# 15   Contains Fast Charging                       NaN                 6.10
# 33                      NaN                       NaN                 6.10
# 45   Contains Fast Charging                      25.0                 6.60
# 75                      NaN                       NaN                 6.26
# ..                      ...                       ...                  ...
# 961                     NaN                       NaN                 6.00
# 962                     NaN                       NaN                 5.20
# 967  Contains Fast Charging                      33.0                 6.30
# 971                     NaN                       NaN                 5.86
# 977                     NaN                       NaN                 5.00
#
#          Resolution  Screen_Rate Punch_Hole/Drop_Notch  Num_of_rear_cam  \
# 6    1170 x 2532 px           60                   NaN                2
# 15   1170 x 2532 px           60                   NaN                2
# 33    828 x 1792 px           60                   NaN                2
# 45   1080 x 2400 px          120      Water Drop Notch                4
# 75    720 x 1600 px           60                   NaN                2
# ..              ...          ...                   ...              ...
# 961  2220 x 1080 px           60                   NaN                3
# 962   720 x 1280 px           60                   NaN                1
# 967  1080 x 2340 px           60                   NaN                3
# 971   720 x 1520 px           60                   NaN                3
# 977    854 x 480 px           60                   NaN                1
#
#     Rear Cam (primary_lens)  Num_of_front_cam Front Cam(primary_lens)  \
# 6                       12                  1                     12
# 15                      12                  1                     12
# 33                      12                  1                     12
# 45                      50                  1                      8
# 75                      13                  1                      5
# ..                      ...               ...                     ...
# 961                     24                  1                     24
# 962                     13                  1                      5
# 967                    108                  1                     32
# 971                     16                  1                      8
# 977                      2                  1                     NaN
#
#     Memory_Card_Supported_Or_Not Capacity  OS_Type OS_Version
# 6      Memory Card Not Supported      NaN      iOS        v16
# 15     Memory Card Not Supported      NaN      iOS        v15
# 33     Memory Card Not Supported      NaN      iOS        v13
# 45         Memory Card Supported      1TB  Android        v12
# 75         Memory Card Supported      NaN   Others         v2
# ..                           ...      ...      ...        ...
# 961        Memory Card Supported    512GB  Android       v8.0
# 962        Memory Card Supported      NaN  Android       v6.0
# 967        Memory Card Supported      1TB  Android        v12
# 971        Memory Card Supported      NaN  Android        v10
# 977    Memory Card Not Supported      NaN  Android        v11
#
# [141 rows x 31 columns]

# %%
df[(df['Battery_Capacity'] < 3750.0)]['brand_names'].value_counts().nlargest(5)
# Out:
# apple      32
# samsung     9
# nokia       5
# vivo        5
# google      3
# Name: brand_names, dtype: int64

# %%
df.head()
# Out:
#    index                      model brand_names  price  rating  SIM_Type  \
# 0      2              OnePlus 11 5G     oneplus  54999    89.0  Dual Sim
# 1      3  OnePlus Nord CE 2 Lite 5G     oneplus  19989    81.0  Dual Sim
# 2      4      Samsung Galaxy A14 5G     samsung  16499    75.0  Dual Sim
# 3      5       Motorola Moto G62 5G    motorola  14999    81.0  Dual Sim
# 4      6         Realme 10 Pro Plus      realme  24999    82.0  Dual Sim
#
#    Contains_5G  Has_NFC  Has_IR_Blaster     Processor_name Processor_Company  \
# 0         True     True           False  Snapdragon 8 Gen2        Snapdragon
# 1         True    False           False     Snapdragon 695        Snapdragon
# 2         True    False           False        Exynos 1330            Exynos
# 3         True    False           False    Snapdragon  695        Snapdragon
# 4         True    False           False     Dimensity 1080         Dimensity
#
#   Number_of_Cores  Processor_Speed(Num)     Processor_speed    RAM     ROM  \
# 0       Octa Core                   3.2   3.2 GHz Processor  12 GB  256 GB
# 1       Octa Core                   2.2   2.2 GHz Processor   6 GB  128 GB
# 2       Octa Core                   2.4   2.4 GHz Processor   4 GB   64 GB
# 3       Octa Core                   2.2   2.2 GHz Processor   6 GB  128 GB
# 4       Octa Core                   2.6   2.6 GHz Processor   6 GB  128 GB
#
#    Battery_Capacity    Fast_Charging_There?  Fast_Charging_in_(Watts)  \
# 0            5000.0  Contains Fast Charging                     100.0
# 1            5000.0  Contains Fast Charging                      33.0
# 2            5000.0  Contains Fast Charging                      15.0
# 3            5000.0  Contains Fast Charging                       NaN
# 4            5000.0  Contains Fast Charging                      67.0
#
#    Screen_Size(inches)      Resolution  Screen_Rate Punch_Hole/Drop_Notch  \
# 0                 6.70  1440 x 3216 px          120            Punch Hole
# 1                 6.59  1080 x 2412 px          120            Punch Hole
# 2                 6.60  1080 x 2408 px           90      Water Drop Notch
# 3                 6.55  1080 x 2400 px          120            Punch Hole
# 4                 6.70  1080 x 2412 px          120            Punch Hole
#
#    Num_of_rear_cam Rear Cam (primary_lens)  Num_of_front_cam  \
# 0                3                     50                  1
# 1                3                     64                  1
# 2                3                     50                  1
# 3                3                     50                  1
# 4                3                    108                  1
#
#   Front Cam(primary_lens) Memory_Card_Supported_Or_Not Capacity  OS_Type  \
# 0                     16     Memory Card Not Supported      NaN  Android
# 1                     16          Memory Card (Hybrid)      1TB  Android
# 2                     13         Memory Card Supported      1TB  Android
# 3                     16          Memory Card (Hybrid)      1TB  Android
# 4                     16     Memory Card Not Supported      NaN  Android
#
#   OS_Version
# 0        v13
# 1        v12
# 2        v13
# 3        v12
# 4        v13

# %% [markdown]
# ##### Fast Charging

# %% [markdown]
# 1. Most of the Phones come today with a Fast Charging Capability. - Can be Used as a Feature

# %%
df['Fast_Charging_There?'].value_counts()
# Out:
# Contains Fast Charging         843
# Fast Charging Not Available    136
# Name: Fast_Charging_There?, dtype: int64

# %%
df['Fast_Charging_There?'] = df['Fast_Charging_There?'].fillna('Fast Charging Not Available')

# %%
plt.figure(figsize = (10,10))
df['Fast_Charging_There?'].value_counts().plot(kind = 'pie',autopct = '%.2f%%')
# Out:
# <AxesSubplot:ylabel='Fast_Charging_There?'>

# %% [markdown]
# ##### Screen Rate

# %% [markdown]
# 1. The most Frequently used Refresh Rates are the 60,90,120 , but there has been an inclusion of new refresh rates such as the 165Hz , 144Hz , 240Hz which are mostly used for the high end purposes i.e  mainly the gaming purposes . The gradual growth in the popularity of the Esports Indstry might be the cause for the development of such high refresh rates.
#
# 2. As High refresh rates are only find in high end devices this can be used as a feature in our ML model.

# %%
df['Screen_Rate'].unique()
# Out:
# array([120,  90,  60, 144, 165, 240], dtype=int64)

# %%
df['Screen_Rate'].value_counts()
# Out:
# 60     369
# 120    342
# 90     219
# 144     39
# 165      9
# 240      1
# Name: Screen_Rate, dtype: int64

# %%
plt.figure(figsize=(8,8))
df['Screen_Rate'].value_counts().plot(kind = 'pie',autopct = '%.2f%%')
# Out:
# <AxesSubplot:ylabel='Screen_Rate'>

# %% [markdown]
# ##### Number of Rear Camera

# %% [markdown]
# 1. Most of the phones in the market come with a triple camera set up.
# 2. It might also be used as a valuable feature in our ML model.

# %%
df['Num_of_rear_cam'].value_counts()
# Out:
# 3    548
# 2    207
# 4    156
# 1     68
# Name: Num_of_rear_cam, dtype: int64

# %%
df.loc[df[df['Num_of_rear_cam'] == 5].index , 'Num_of_rear_cam'] = 4

# %%
df['Num_of_rear_cam'].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data = df ,  x = 'Num_of_rear_cam')
# Out:
# <AxesSubplot:xlabel='Num_of_rear_cam', ylabel='count'>

# %% [markdown]
# ##### Operating System.

# %%
df['OS_Type'].value_counts()
# Out:
# Android    892
# iOS         46
# Others      11
# Name: OS_Type, dtype: int64

# %%
df['OS_Version'].value_counts()
# Out:
# v12        386
# v11        271
# v13         95
# v10         68
# v9.0        28
# v10.0       23
# v16         15
# v15         12
# v8.1        10
# v14          6
# v11.0        4
# v2.0         4
# v8.0         4
# v15.0        3
# v12.1        2
# v6.0         2
# v14.0        2
# v5.1.1       2
# OS           2
# (Series      1
# v7.1         1
# v17          1
# v5.1         1
# v2           1
# v12.3        1
# v13.0        1
# v9           1
# Name: OS_Version, dtype: int64

# %%
df.columns
# Out:
# Index(['index', 'model', 'brand_names', 'price', 'rating', 'SIM_Type',
#        'Contains_5G', 'Has_NFC', 'Has_IR_Blaster', 'Processor_name',
#        'Processor_Company', 'Number_of_Cores', 'Processor_Speed(Num)',
#        'Processor_speed', 'RAM', 'ROM', 'Battery_Capacity',
#        'Fast_Charging_There?', 'Fast_Charging_in_(Watts)',
#        'Screen_Size(inches)', 'Resolution', 'Screen_Rate',
#        'Punch_Hole/Drop_Notch', 'Num_of_rear_cam', 'Rear Cam (primary_lens)',
#        'Num_of_front_cam', 'Front Cam(primary_lens)',
#        'Memory_Card_Supported_Or_Not', 'Capacity', 'OS_Type', 'OS_Version'],
#       dtype='object')

# %% [markdown]
# ## Note : This ends our Univariate Analysis

# %% [markdown]
# ### Some of the most Important Columns From training a ML model Point of View are :
#
# 1. Brand Name
# 2. Rating
# 3. Contains_5G
# 4. Has_NFC
# 5. Processor_Name
# 6. Processor_Company
# 7. RAM and ROM (Together)
# 8. Screen_Rate
# 9. Rear Camera Primary Lens
# 10. Front Camera Primary Lens
# 11. Memory Card Support
# 12. OS Type and OS version
#
#
# Note : The output of the ML model would be to predict the Price so the dependency of the price column has to be checked with the above mentioned columns or combination of the above mentioned columns

# %% [markdown]
# # Bivariate Analysis

# %%
df.head(2)
# Out:
#    index                      model brand_names  price  rating  SIM_Type  \
# 0      2              OnePlus 11 5G     oneplus  54999    89.0  Dual Sim
# 1      3  OnePlus Nord CE 2 Lite 5G     oneplus  19989    81.0  Dual Sim
#
#    Contains_5G  Has_NFC  Has_IR_Blaster     Processor_name Processor_Company  \
# 0         True     True           False  Snapdragon 8 Gen2        Snapdragon
# 1         True    False           False     Snapdragon 695        Snapdragon
#
#   Number_of_Cores  Processor_Speed(Num)     Processor_speed    RAM     ROM  \
# 0       Octa Core                   3.2   3.2 GHz Processor  12 GB  256 GB
# 1       Octa Core                   2.2   2.2 GHz Processor   6 GB  128 GB
#
#    Battery_Capacity    Fast_Charging_There?  Fast_Charging_in_(Watts)  \
# 0            5000.0  Contains Fast Charging                     100.0
# 1            5000.0  Contains Fast Charging                      33.0
#
#    Screen_Size(inches)      Resolution  Screen_Rate Punch_Hole/Drop_Notch  \
# 0                 6.70  1440 x 3216 px          120            Punch Hole
# 1                 6.59  1080 x 2412 px          120            Punch Hole
#
#    Num_of_rear_cam Rear Cam (primary_lens)  Num_of_front_cam  \
# 0                3                     50                  1
# 1                3                     64                  1
#
#   Front Cam(primary_lens) Memory_Card_Supported_Or_Not Capacity  OS_Type  \
# 0                     16     Memory Card Not Supported      NaN  Android
# 1                     16          Memory Card (Hybrid)      1TB  Android
#
#   OS_Version
# 0        v13
# 1        v12

# %% [markdown]
# ### Price Vs Brand

# %% [markdown]
# 1. There is a clear dependency of Price on Brand column.

# %%
# lets plot the graph of only those brands of phones which have more than 30 listed phones on SmartPrix Website.

# %%
t =  df.groupby('brand_names').size().reset_index()

# %%
t.columns = ['Brands','Count']

# %%
t.head()
# Out:
#       Brands  Count
# 0      apple     46
# 1       asus      7
# 2  blackview      1
# 3        blu      1
# 4        cat      1

# %%
t = t[t['Count'] > 10]

# %%
t
# Out:
#       Brands  Count
# 0      apple     46
# 9     google     14
# 10     honor     13
# 11    huawei     14
# 13   infinix     29
# 14      iqoo     32
# 25  motorola     52
# 26     nokia     17
# 29   oneplus     42
# 30      oppo     88
# 32      poco     41
# 33    realme     97
# 36   samsung    132
# 40     tecno     33
# 42      vivo    111
# 43    xiaomi    133

# %%
df2  = df[df['brand_names'].isin(t['Brands'].to_list())]

# %%
plt.figure(figsize = (14,8))
sns.barplot(data = df2 ,  x = 'brand_names', y = 'price',estimator=np.median)
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize = (14,10))
ax = sns.violinplot(data = df2 , x = 'brand_names' , y = 'price')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ### Price Vs Rating

# %% [markdown]
# 1. Here we can clearly see that as rating increases there is a very minute gradual change in the price of the Mobile Phones . But There are Phones which have very good rating and they also have decent price w.r.t the specs provided and the overall rating.
# 2. So Rating does matter in a way for deciding the Price but not so much.
# 3. There are a lot of Phones in the Range of 75 to 80 (in terms of Ratings) and they have  their price near to 25000 , These may be the Phones which get bought most frequently.

# %%
sns.relplot(data = df2 , x = 'rating' , y = 'price')

# %%
sns.displot(data = df2 , x = 'rating' , y = 'price', kind = 'hist')
sns.displot(data = df2 , x = 'rating' , y = 'price' ,kind = 'kde')

# %%
sns.barplot(data = df2 , x = 'SIM_Type' , y = 'price',estimator = np.median)
# Out:
# <AxesSubplot:xlabel='SIM_Type', ylabel='price'>

# %% [markdown]
# ### 5G Availability

# %% [markdown]
# 1. Phones that have the feature of 5G availability they have a higher Price.

# %%
sns.barplot(data =df , x = 'Contains_5G' , y='price')
# Out:
# <AxesSubplot:xlabel='Contains_5G', ylabel='price'>

# %%
df.corr()
# Out:
#                              index     price    rating  Contains_5G   Has_NFC  \
# index                     1.000000 -0.001620 -0.174663    -0.220240 -0.066170
# price                    -0.001620  1.000000  0.439928     0.451913  0.567767
# rating                   -0.174663  0.439928  1.000000     0.600182  0.479951
# Contains_5G              -0.220240  0.451913  0.600182     1.000000  0.492955
# Has_NFC                  -0.066170  0.567767  0.479951     0.492955  1.000000
# Has_IR_Blaster           -0.038573 -0.033536  0.157418     0.108079 -0.035413
# Processor_Speed(Num)     -0.113518  0.676673  0.627908     0.613634  0.614240
# Battery_Capacity         -0.064620 -0.216435 -0.068412    -0.020793 -0.166058
# Fast_Charging_in_(Watts) -0.050928  0.315776  0.532550     0.430476  0.367028
# Screen_Size(inches)      -0.056683  0.245002  0.290275     0.228559  0.122493
# Screen_Rate              -0.201995  0.368265  0.613942     0.615879  0.421735
# Num_of_rear_cam          -0.012584  0.213585  0.512786     0.219502  0.173792
# Num_of_front_cam          0.045922  0.122332  0.132456     0.053754  0.061427
#
#                           Has_IR_Blaster  Processor_Speed(Num)  \
# index                          -0.038573             -0.113518
# price                          -0.033536              0.676673
# rating                          0.157418              0.627908
# Contains_5G                     0.108079              0.613634
# Has_NFC                        -0.035413              0.614240
# Has_IR_Blaster                  1.000000              0.098672
# Processor_Speed(Num)            0.098672              1.000000
# Battery_Capacity                0.125954             -0.076340
# Fast_Charging_in_(Watts)        0.190251              0.590299
# Screen_Size(inches)             0.128611              0.311459
# Screen_Rate                     0.181150              0.557498
# Num_of_rear_cam                 0.195643              0.269229
# Num_of_front_cam               -0.024889              0.120293
#
#                           Battery_Capacity  Fast_Charging_in_(Watts)  \
# index                            -0.064620                 -0.050928
# price                            -0.216435                  0.315776
# rating                           -0.068412                  0.532550
# Contains_5G                      -0.020793                  0.430476
# Has_NFC                          -0.166058                  0.367028
# Has_IR_Blaster                    0.125954                  0.190251
# Processor_Speed(Num)             -0.076340                  0.590299
# Battery_Capacity                  1.000000                 -0.064203
# Fast_Charging_in_(Watts)         -0.064203                  1.000000
# Screen_Size(inches)               0.599602                  0.266355
# Screen_Rate                       0.177410                  0.550133
# Num_of_rear_cam                   0.289083                  0.143575
# Num_of_front_cam                 -0.079953                  0.014306
#
#                           Screen_Size(inches)  Screen_Rate  Num_of_rear_cam  \
# index                               -0.056683    -0.201995        -0.012584
# price                                0.245002     0.368265         0.213585
# rating                               0.290275     0.613942         0.512786
# Contains_5G                          0.228559     0.615879         0.219502
# Has_NFC                              0.122493     0.421735         0.173792
# Has_IR_Blaster                       0.128611     0.181150         0.195643
# Processor_Speed(Num)                 0.311459     0.557498         0.269229
# Battery_Capacity                     0.599602     0.177410         0.289083
# Fast_Charging_in_(Watts)             0.266355     0.550133         0.143575
# Screen_Size(inches)                  1.000000     0.308107         0.390067
# Screen_Rate                          0.308107     1.000000         0.308563
# Num_of_rear_cam                      0.390067     0.308563         1.000000
# Num_of_front_cam                     0.066414     0.023967         0.120217
#
#                           Num_of_front_cam
# index                             0.045922
# price                             0.122332
# rating                            0.132456
# Contains_5G                       0.053754
# Has_NFC                           0.061427
# Has_IR_Blaster                   -0.024889
# Processor_Speed(Num)              0.120293
# Battery_Capacity                 -0.079953
# Fast_Charging_in_(Watts)          0.014306
# Screen_Size(inches)               0.066414
# Screen_Rate                       0.023967
# Num_of_rear_cam                   0.120217
# Num_of_front_cam                  1.000000

# %% [markdown]
# 1. The Price of the Mobile Phone is most affected by the Type of Processor used in it , which then defines the Processor Speed.
# 2. As we found ,  the price also depends to a great extent on the rating and the availability of the 5G Technology , as NFC feature are only found in the high end Phones thus Price also highly depends in the availability of the NFC.
# 3. In general with increase in Price the Battery Capacity of the Mobile Phones is reduced , this happens because most of the times the high end phones are the 'Flagship' phones of that brand hence they also need to work towards the aesthetics of the phone i.e making it look good , slim etc also the costly mobile Phones are filled with other different features like wireless charging, better camera, OIS and a ton of other sensors,these needs space so they ultimately compromise with the battery size and hence less battery Capacity.

# %%
df.head(2)
# Out:
#    index                      model brand_names  price  rating  SIM_Type  \
# 0      2              OnePlus 11 5G     oneplus  54999    89.0  Dual Sim
# 1      3  OnePlus Nord CE 2 Lite 5G     oneplus  19989    81.0  Dual Sim
#
#    Contains_5G  Has_NFC  Has_IR_Blaster     Processor_name Processor_Company  \
# 0         True     True           False  Snapdragon 8 Gen2        Snapdragon
# 1         True    False           False     Snapdragon 695        Snapdragon
#
#   Number_of_Cores  Processor_Speed(Num)     Processor_speed    RAM     ROM  \
# 0       Octa Core                   3.2   3.2 GHz Processor  12 GB  256 GB
# 1       Octa Core                   2.2   2.2 GHz Processor   6 GB  128 GB
#
#    Battery_Capacity    Fast_Charging_There?  Fast_Charging_in_(Watts)  \
# 0            5000.0  Contains Fast Charging                     100.0
# 1            5000.0  Contains Fast Charging                      33.0
#
#    Screen_Size(inches)      Resolution  Screen_Rate Punch_Hole/Drop_Notch  \
# 0                 6.70  1440 x 3216 px          120            Punch Hole
# 1                 6.59  1080 x 2412 px          120            Punch Hole
#
#    Num_of_rear_cam Rear Cam (primary_lens)  Num_of_front_cam  \
# 0                3                     50                  1
# 1                3                     64                  1
#
#   Front Cam(primary_lens) Memory_Card_Supported_Or_Not Capacity  OS_Type  \
# 0                     16     Memory Card Not Supported      NaN  Android
# 1                     16          Memory Card (Hybrid)      1TB  Android
#
#   OS_Version
# 0        v13
# 1        v12

# %%
df.dtypes
# Out:
# index                             int64
# model                            object
# brand_names                      object
# price                             int64
# rating                          float64
# SIM_Type                         object
# Contains_5G                        bool
# Has_NFC                            bool
# Has_IR_Blaster                     bool
# Processor_name                   object
# Processor_Company                object
# Number_of_Cores                  object
# Processor_Speed(Num)            float64
# Processor_speed                  object
# RAM                              object
# ROM                              object
# Battery_Capacity                float64
# Fast_Charging_There?             object
# Fast_Charging_in_(Watts)        float64
# Screen_Size(inches)             float64
# Resolution                       object
# Screen_Rate                       int64
# Punch_Hole/Drop_Notch            object
# Num_of_rear_cam                   int64
# Rear Cam (primary_lens)          object
# Num_of_front_cam                  int64
# Front Cam(primary_lens)          object
# Memory_Card_Supported_Or_Not     object
# Capacity                         object
# OS_Type                          object
# OS_Version                       object
# dtype: object

# %%
sns.relplot(data = df , y = 'price' , x = 'Processor_Speed(Num)')

# %% [markdown]
# Although the graph shows that there is a dependency of the price of the mobile phone on the processor speed but also it can be clearly seen that there are phones which are providing with the same processor speed from price range from as low as 25000 to 175000 .

# %%
pd.crosstab(df['Processor_Company'],df['Number_of_Cores'])
# Out:
# Number_of_Cores    Dual Core  Hexa Core  Octa Core  Quad Core
# Processor_Company
# A13                        0          5          0          0
# Bionic                     0         34          1          0
# Dimensity                  0          0        176          0
# Exynos                     0          0         50          0
# Fusion                     0          0          0          1
# Google                     0          0          9          0
# Helio                      0          0        189         11
# Kirin                      0          0          6          0
# Mediatek                   0          0          0          1
# Qualcomm                   0          0          2          3
# SC9863A                    0          0          2          0
# Snapdragon                 1          0        402          3
# Spreadtrum                 0          0          0          4
# Tiger                      0          0         19          5
# Unisoc                     0          0         23          3

# %% [markdown]
# As Bionic,A13 Processors are only used by the Apple hence it is quite clear that most of the Apple mobile phones work on Hexa Core Processors.

# %%
sns.pointplot(data =  df , x = 'Number_of_Cores' , y = 'price')
# Out:
# <AxesSubplot:xlabel='Number_of_Cores', ylabel='price'>

# %%
sns.barplot(data =  df , x = 'Number_of_Cores' , y = 'price')
# Out:
# <AxesSubplot:xlabel='Number_of_Cores', ylabel='price'>

# %% [markdown]
# As mostly the Apple Mobile Phones are using the Hexa Core Processor that might be the reason for such Trends in Prices.

# %%
temp_df = df.groupby(['RAM','ROM'])['index'].count().reset_index().sort_values(by = 'index',ascending = False)

# %%
temp_df = temp_df.sort_values(by = 'index',ascending = False).head(10)
temp_df
# Out:
#       RAM     ROM  index
# 29   8 GB  128 GB    267
# 24   6 GB  128 GB    190
# 21   4 GB   64 GB    143
# 4   12 GB  256 GB     69
# 30   8 GB  256 GB     68
# 17   4 GB  128 GB     62
# 15   3 GB   32 GB     37
# 27   6 GB   64 GB     29
# 11   2 GB   32 GB     24
# 16   3 GB   64 GB     15

# %% [markdown]
# 1. The Above mentioned combination of the RAM and ROM are most widely found in the mobile phones available in the market.

# %%
temp_df['Ram-Rom'] = temp_df['RAM'] + '-' + temp_df['ROM']

# %%
temp_df = temp_df.iloc[:,2:]

# %%
temp_df =temp_df.iloc[:,[1,0]]

# %%
temp_df.columns = ['Ram-Rom','Count']

# %%
temp_df
# Out:
#          Ram-Rom  Count
# 29   8 GB-128 GB    267
# 24   6 GB-128 GB    190
# 21    4 GB-64 GB    143
# 4   12 GB-256 GB     69
# 30   8 GB-256 GB     68
# 17   4 GB-128 GB     62
# 15    3 GB-32 GB     37
# 27    6 GB-64 GB     29
# 11    2 GB-32 GB     24
# 16    3 GB-64 GB     15

# %%
sns.barplot(data = temp_df , x = 'Ram-Rom' , y = 'Count')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## Effect of RAM, ROM on Price

# %%
df3 = df.copy()

# %%
df3['RAM'] = df3['RAM'].str.split(' ').str.get(0)
df3['ROM'] = df3['ROM'].str.split(' ').str.get(0)

# %%
df3.head()
# Out:
#    index                      model brand_names  price  rating  SIM_Type  \
# 0      2              OnePlus 11 5G     oneplus  54999    89.0  Dual Sim
# 1      3  OnePlus Nord CE 2 Lite 5G     oneplus  19989    81.0  Dual Sim
# 2      4      Samsung Galaxy A14 5G     samsung  16499    75.0  Dual Sim
# 3      5       Motorola Moto G62 5G    motorola  14999    81.0  Dual Sim
# 4      6         Realme 10 Pro Plus      realme  24999    82.0  Dual Sim
#
#    Contains_5G  Has_NFC  Has_IR_Blaster     Processor_name Processor_Company  \
# 0         True     True           False  Snapdragon 8 Gen2        Snapdragon
# 1         True    False           False     Snapdragon 695        Snapdragon
# 2         True    False           False        Exynos 1330            Exynos
# 3         True    False           False    Snapdragon  695        Snapdragon
# 4         True    False           False     Dimensity 1080         Dimensity
#
#   Number_of_Cores  Processor_Speed(Num)     Processor_speed RAM  ROM  \
# 0       Octa Core                   3.2   3.2 GHz Processor  12  256
# 1       Octa Core                   2.2   2.2 GHz Processor   6  128
# 2       Octa Core                   2.4   2.4 GHz Processor   4   64
# 3       Octa Core                   2.2   2.2 GHz Processor   6  128
# 4       Octa Core                   2.6   2.6 GHz Processor   6  128
#
#    Battery_Capacity    Fast_Charging_There?  Fast_Charging_in_(Watts)  \
# 0            5000.0  Contains Fast Charging                     100.0
# 1            5000.0  Contains Fast Charging                      33.0
# 2            5000.0  Contains Fast Charging                      15.0
# 3            5000.0  Contains Fast Charging                       NaN
# 4            5000.0  Contains Fast Charging                      67.0
#
#    Screen_Size(inches)      Resolution  Screen_Rate Punch_Hole/Drop_Notch  \
# 0                 6.70  1440 x 3216 px          120            Punch Hole
# 1                 6.59  1080 x 2412 px          120            Punch Hole
# 2                 6.60  1080 x 2408 px           90      Water Drop Notch
# 3                 6.55  1080 x 2400 px          120            Punch Hole
# 4                 6.70  1080 x 2412 px          120            Punch Hole
#
#    Num_of_rear_cam Rear Cam (primary_lens)  Num_of_front_cam  \
# 0                3                     50                  1
# 1                3                     64                  1
# 2                3                     50                  1
# 3                3                     50                  1
# 4                3                    108                  1
#
#   Front Cam(primary_lens) Memory_Card_Supported_Or_Not Capacity  OS_Type  \
# 0                     16     Memory Card Not Supported      NaN  Android
# 1                     16          Memory Card (Hybrid)      1TB  Android
# 2                     13         Memory Card Supported      1TB  Android
# 3                     16          Memory Card (Hybrid)      1TB  Android
# 4                     16     Memory Card Not Supported      NaN  Android
#
#   OS_Version
# 0        v13
# 1        v12
# 2        v13
# 3        v12
# 4        v13

# %%
df3['RAM'] = df3['RAM'].astype(float)
df3['ROM'] = df3['ROM'].astype(float)

# %%
df3.corr()['price']
# Out:
# index                      -0.001620
# price                       1.000000
# rating                      0.439928
# Contains_5G                 0.451913
# Has_NFC                     0.567767
# Has_IR_Blaster             -0.033536
# Processor_Speed(Num)        0.676673
# RAM                         0.011653
# ROM                         0.575273
# Battery_Capacity           -0.216435
# Fast_Charging_in_(Watts)    0.315776
# Screen_Size(inches)         0.245002
# Screen_Rate                 0.368265
# Num_of_rear_cam             0.213585
# Num_of_front_cam            0.122332
# Name: price, dtype: float64

# %% [markdown]
# According to this the price is more affected by the ROM than that of the RAM.

# %%
sns.barplot(data = df ,  x = 'RAM', y = 'price')
plt.xticks(rotation = 75)
plt.show()

# %%
sns.barplot(data = df ,  x = 'ROM', y = 'price')
plt.xticks(rotation = 75)
plt.show()

# %%
t_df=  df.groupby('RAM').agg({
    'price':'mean',
    'index':'count'
})
t_df
# Out:
#                price  index
# RAM
# 1 GB     6683.125000      8
# 12 GB   69510.204819     83
# 16 GB   62330.333333      9
# 18 GB   82994.500000      2
# 2 GB     7102.193548     31
# 256 MB   3999.000000      1
# 3 GB    10723.277778     54
# 4 GB    15837.009302    215
# 512 MB   6549.000000      2
# 6 GB    29306.649573    234
# 64 MB    3589.000000      1
# 8 GB    37138.020772    337

# %%
t_df.columns = ['Average','Count']

# %%
t_df = t_df.reset_index()

# %%
t_df
# Out:
#        RAM       Average  Count
# 0     1 GB   6683.125000      8
# 1    12 GB  69510.204819     83
# 2    16 GB  62330.333333      9
# 3    18 GB  82994.500000      2
# 4     2 GB   7102.193548     31
# 5   256 MB   3999.000000      1
# 6     3 GB  10723.277778     54
# 7     4 GB  15837.009302    215
# 8   512 MB   6549.000000      2
# 9     6 GB  29306.649573    234
# 10   64 MB   3589.000000      1
# 11    8 GB  37138.020772    337

# %%
fig,ax = plt.subplots(ncols = 2 , nrows = 1,figsize = (20,8))
sns.barplot(data = t_df ,  x = 'ROM', y = 'Average',ax = ax[0])
sns.barplot(data=t_df , x = 'ROM' ,y = 'Count' , ax = ax[1])
plt.show()

# %% [markdown]
# 1. Here we can see that the Average of the 1 TB , 512 GB are among the highest , but their count is among the lowest .which shows that their per unit price is very high. and for ROM such as that of 128GB , 256 GB 64 GB  , their usag is more and thus their average price decreases.
# 2. But as we go from 128 MB( the lowest ) to 1 TB (the highest) the average price actuallt increases.

# %%
fig,ax = plt.subplots(ncols = 2 , nrows = 1,figsize = (20,8))
sns.barplot(data = t_df ,  x = 'RAM', y = 'Average',ax = ax[0])
sns.barplot(data=t_df , x = 'RAM' ,y = 'Count' , ax = ax[1])
plt.show()

# %% [markdown]
# 1. Here also as we go from 64 MB( the lowest) to 18 GB (the highest) the average Price Increases.

# %% [markdown]
# ## Battery Capacity

# %%
sns.relplot( x = df['Battery_Capacity'] , y= df['price'])

# %% [markdown]
# with increase in the Battery capacity there is no such increase in the price of the mobile phones., Also there are many such mobile phones in the range of 4000 to roughly 5600 where for the same battery capacity we can make a purchase at a very affordable price.

# %%
df.corr()['Screen_Size(inches)']
# Out:
# index                      -0.056683
# price                       0.245002
# rating                      0.290275
# Contains_5G                 0.228559
# Has_NFC                     0.122493
# Has_IR_Blaster              0.128611
# Processor_Speed(Num)        0.311459
# Battery_Capacity            0.599602
# Fast_Charging_in_(Watts)    0.266355
# Screen_Size(inches)         1.000000
# Screen_Rate                 0.308107
# Num_of_rear_cam             0.390067
# Num_of_front_cam            0.066414
# Name: Screen_Size(inches), dtype: float64

# %% [markdown]
# ## Availability Of Fast Charging

# %%
sns.catplot(kind = 'box' , x = 'Fast_Charging_There?' , y  ='price', data = df)

# %%
df.drop(index = 787 , inplace = True)

# %%
df['price'].describe()
# Out:
# count       979.000000
# mean      30890.501532
# std       29872.199338
# min        3499.000000
# 25%       12999.000000
# 50%       19990.000000
# 75%       34999.000000
# max      199990.000000
# Name: price, dtype: float64
